# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#import dataset
df=pd.read_csv('Medical Inventory Optimaization Dataset.csv')
df
# Out:
#       Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0            Sale  12018098765   Specialisation6  Department1  06-01-2022
# 1            Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2            Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3            Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4            Sale  12018117928   Specialisation5  Department1  12/21/2022
# ...           ...          ...               ...          ...         ...
# 14213        Sale  12018099994  Specialisation39  Department1   6/19/2022
# 14214        Sale  12018047025   Specialisation4  Department1   2/24/2022
# 14215        Sale  12018017139   Specialisation1  Department1   6/27/2022
# 14216        Sale  12018044140  Specialisation20  Department1   7/30/2022
# 14217        Sale  12018116820  Specialisation26  Department1  10/24/2022
#
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %% [markdown]
# # EDA

# %%
#shape
df.shape
# Out:
# (14218, 14)

# %%
#checking missing values
df.isna().sum()
# Out:
# Typeofsales          0
# Patient_ID           0
# Specialisation       0
# Dept                 0
# Dateofbill           0
# Quantity             0
# ReturnQuantity       0
# Final_Cost           0
# Final_Sales          0
# RtnMRP               0
# Formulation        653
# DrugName          1668
# SubCat            1668
# SubCat1           1692
# dtype: int64

# %%
#checking duplicates
df.duplicated().sum()
# Out:
# 26

# %%
#checking datatype
df.dtypes
# Out:
# Typeofsales        object
# Patient_ID          int64
# Specialisation     object
# Dept               object
# Dateofbill         object
# Quantity            int64
# ReturnQuantity      int64
# Final_Cost        float64
# Final_Sales       float64
# RtnMRP            float64
# Formulation        object
# DrugName           object
# SubCat             object
# SubCat1            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14218 entries, 0 to 14217
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Typeofsales     14218 non-null  object
#  1   Patient_ID      14218 non-null  int64
#  2   Specialisation  14218 non-null  object
#  3   Dept            14218 non-null  object
#  4   Dateofbill      14218 non-null  object
#  5   Quantity        14218 non-null  int64
#  6   ReturnQuantity  14218 non-null  int64
#  7   Final_Cost      14218 non-null  float64
#  8   Final_Sales     14218 non-null  float64
#  9   RtnMRP          14218 non-null  float64
#  10  Formulation     13565 non-null  object
#  11  DrugName        12550 non-null  object
#  12  SubCat          12550 non-null  object
#  13  SubCat1         12526 non-null  object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#          Patient_ID      Quantity  ReturnQuantity    Final_Cost   Final_Sales  \
# count  1.421800e+04  14218.000000    14218.000000  14218.000000  14218.000000
# mean   1.201809e+10      2.231748        0.291954    124.823957    234.038300
# std    2.810229e+04      5.132043        1.643322    464.782794    671.261572
# min    1.201800e+10      0.000000        0.000000     40.000000      0.000000
# 25%    1.201808e+10      1.000000        0.000000     44.928000     47.815000
# 50%    1.201809e+10      1.000000        0.000000     53.650000     86.424000
# 75%    1.201811e+10      2.000000        0.000000     77.800000    181.000000
# max    1.201813e+10    150.000000       50.000000  33178.000000  39490.000000
#
#              RtnMRP
# count  14218.000000
# mean      29.126755
# std      182.262335
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     8014.000000

# %%
# checking typesales
print('unique:',df['Typeofsales'].unique())
print('nunique:',df['Typeofsales'].nunique())
print('value_count:',df['Typeofsales'].value_counts())
# Out:
# unique: ['Sale' 'Return']
# nunique: 2
# value_count: Typeofsales
# Sale      12537
# Return     1681
# Name: count, dtype: int64

# %%
#check specialisation
print('unique:',df['Specialisation'].nunique())
print('value_count:',df['Specialisation'].value_counts())
# Out:
# unique: 58
# value_count: Specialisation
# Specialisation4     3999
# Specialisation7     2098
# Specialisation3      734
# Specialisation2      609
# Specialisation8      594
# Specialisation20     554
# Specialisation11     516
# Specialisation16     509
# Specialisation1      440
# Specialisation14     436
# Specialisation5      390
# Specialisation21     360
# Specialisation26     342
# Specialisation6      251
# Specialisation23     249
# Specialisation25     201
# Specialisation31     184
# Specialisation17     178
# Specialisation9      158
# Specialisation15     143
# Specialisation42     132
# Specialisation27     117
# Specialisation10     107
# Specialisation50     100
# Specialisation33      99
# Specialisation55      91
# Specialisation43      74
# Specialisation45      55
# Specialisation34      53
# Specialisation39      47
# Specialisation41      44
# Specialisation40      43
# Specialisation28      34
# Specialisation19      30
# Specialisation48      24
# ...

# %%
# checking dept
print('unique:',df['Dept'].unique())
print('nunique:',df['Dept'].nunique())
print('value_count:',df['Dept'].value_counts())
# Out:
# unique: ['Department1' 'Department3' 'Department2']
# nunique: 3
# value_count: Dept
# Department1    12440
# Department2     1566
# Department3      212
# Name: count, dtype: int64

# %%
# checking drugname
print('unique:',df['DrugName'].unique())
print('nunique:',df['DrugName'].nunique())
print('value_count:',df['DrugName'].value_counts())
# Out:
# unique: ['ZINC ACETATE 20MG/5ML SYP' 'CEFTAZIDIME 2GM+AVIBACTAM 500MG'
#  'EPTIFIBATIDE 0.75MG/ML' 'WATER FOR INJECTION 10ML SOLUTION'
#  'LORAZEPAM 1MG' 'SALBUTAMOL 2.5MG' 'FUROSEMIDE 10MG/ML'
#  'SODIUM CHLORIDE IVF 100ML' 'SODIUM BICARBONATE 8.5% INJ'
#  'PEPTIDE BASED DIET POWDER' 'MULTIPLE ELECTROLYTES 500ML IVF'
#  'N-ACETYLCYSTEINE 1000MG/5ML INJ' 'PROPOFOL 1% 20ML INJ'
#  'PARACETAMOL 150MG' 'VITAMIN K 1ML INJ' nan 'SODIUM CHLORIDE 0.9%'
#  'PARACETAMOL 1GM IV INJ' 'LIGNOCAINE HYDROCHLORIDE 2% INJ'
#  'POLYANTIBIOTIC RESISTANT BACILLUS CLAUSII 2BILLION SPORES'
#  'HUMAN ALBUMIN 25% INJ' 'POTASSIUM CHLORIDE 150MG' 'SEVOFLURANE 99.97%'
#  'SODIUM CHLORIDE 0.85G + POTASSIUM CHLORIDE 0.038G + CALCIUM CHLORIDE 0.070G'
#  'CALCIUM 250MG + VITAMIN D3 125IU' 'FENTANYL 100MCG/2ML'
#  'NORADRENALINE 2ML INJ' 'PIPERACILLIN 4GM+ TAZOBACTAM 500MG'
#  'RIFABUTIN 150MG CAP' 'HYDROCORTISONE 100MG INJ' 'ONDANSETRON 2MG/ML'
# ...

# %%
#check formulation
print('unique:',df['Formulation'].unique())
print('nunique:',df['Formulation'].nunique())
print('value_count:',df['Formulation'].value_counts())
# Out:
# unique: ['Form1' 'Form2' nan 'Patent' 'Form3']
# nunique: 4
# value_count: Formulation
# Form1     11622
# Form2      1325
# Patent      539
# Form3        79
# Name: count, dtype: int64

# %%
# check subcat
print('unique:',df['SubCat'].unique())
print('nunique:',df['SubCat'].nunique())
print('value_count:',df['SubCat'].value_counts())
# Out:
# unique: ['SYRUP & SUSPENSION' 'INJECTIONS' 'TABLETS & CAPSULES'
#  'INHALERS & RESPULES' 'IV FLUIDS, ELECTROLYTES, TPN'
#  'NUTRITIONAL SUPPLEMENTS' nan 'OINTMENTS, CREAMS & GELS'
#  'LIQUIDS & SOLUTIONS' 'PESSARIES & SUPPOSITORIES' 'DROPS' 'POWDER'
#  'LOTIONS' 'SPRAY' 'VACCINE' 'PATCH' 'SACHETS' 'SOLUTION']
# nunique: 17
# value_count: SubCat
# INJECTIONS                      6500
# IV FLUIDS, ELECTROLYTES, TPN    2709
# TABLETS & CAPSULES              1505
# INHALERS & RESPULES              469
# OINTMENTS, CREAMS & GELS         364
# LIQUIDS & SOLUTIONS              265
# SYRUP & SUSPENSION               237
# POWDER                           216
# NUTRITIONAL SUPPLEMENTS          126
# PESSARIES & SUPPOSITORIES         55
# DROPS                             53
# VACCINE                           19
# SPRAY                             12
# PATCH                             11
# LOTIONS                            5
# SOLUTION                           3
# ...

# %%
#checking subcat1
print('unique:',df['SubCat1'].unique())
print('nunique:',df['SubCat1'].nunique())
print('value_count:',df['SubCat1'].value_counts())
# Out:
# unique: ['VITAMINS & MINERALS' 'ANTI-INFECTIVES'
#  'CARDIOVASCULAR & HEMATOPOIETIC SYSTEM'
#  'INTRAVENOUS & OTHER STERILE SOLUTIONS' 'CENTRAL NERVOUS SYSTEM'
#  'RESPIRATORY SYSTEM' 'NUTRITION' 'ANAESTHETICS' nan
#  'GASTROINTESTINAL & HEPATOBILIARY SYSTEM' 'HORMONES'
#  'MUSCULO-SKELETAL SYSTEM' 'ENDOCRINE & METABOLIC SYSTEM' 'OPHTHALMOLOGY'
#  'IMMUNOLOGY' 'EAR & MOUTH/ THROAT' 'GENITO-URINARY SYSTEM' 'DERMATOLOGY'
#  'MISCELLANEOUS' 'ONCOLOGY' 'CARDIIVASCULAR&HEMATOPOIETIC SYSTEM'
#  'ANTIDOTES, DETOXIFYING AGENTS & DRUGS USED IN SUBSTANCE DEPENDENCE']
# nunique: 21
# value_count: SubCat1
# INTRAVENOUS & OTHER STERILE SOLUTIONS                                 3192
# GASTROINTESTINAL & HEPATOBILIARY SYSTEM                               1738
# ANTI-INFECTIVES                                                       1647
# CARDIOVASCULAR & HEMATOPOIETIC SYSTEM                                 1480
# CENTRAL NERVOUS SYSTEM                                                1262
# ...

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# # First Order Business Decision

# %%
# mean,median,mode

# %% [markdown]
# # Mean

# %%
#mean
print('Mean of the Quantity:',df['Quantity'].mean())
print('Mean of the ReturnQuantity:',df['ReturnQuantity'].mean())
print('Mean of the Final_Cost:',df['Final_Cost'].mean())
print('Mean of the Final_Sales:',df['Final_Sales'].mean())
print('Mean of the RtnMRP:',df['RtnMRP'].mean())
# Out:
# Mean of the Quantity: 2.2317484878323253
# Mean of the ReturnQuantity: 0.2919538613025742
# Mean of the Final_Cost: 124.82395695597131
# Mean of the Final_Sales: 234.0383004642003
# Mean of the RtnMRP: 29.126754958503305

# %% [markdown]
# # Median

# %%
#median
print('Median of the Quantity:',df['Quantity'].median())
print('Median of the ReturnQuantity:',df['ReturnQuantity'].median())
print('Median of the Final_Cost:',df['Final_Cost'].median())
print('Median of the Final_Sales:',df['Final_Sales'].median())
print('Median of the RtnMRP:',df['RtnMRP'].median())
# Out:
# Median of the Quantity: 1.0
# Median of the ReturnQuantity: 0.0
# Median of the Final_Cost: 53.65
# Median of the Final_Sales: 86.424
# Median of the RtnMRP: 0.0

# %% [markdown]
# # Mode

# %%
#mode
print('1.Mode of the Typeofsales:',df['Typeofsales'].mode())
print('2.Mode of the Specialisation:',df['Specialisation'].mode())
print('3.Mode of the Dept:',df['Dept'].mode())
print('4.Mode of the Dateofbill:',df['Dateofbill'].mode())
print('5.Mode of the Quantity:',df['Quantity'].mode())
print('6.Mode of the ReturnQuantity:',df['ReturnQuantity'].mode())
print('7.Mode of the Final_Cost:',df['Final_Cost'].mode())
print('8.Mode of the Final_Sales:',df['Final_Sales'].mode())
print('9.Mode of the RtnMRP:',df['RtnMRP'].mode())
print('10.Mode of the Formulation:',df['Formulation'].mode())
print('11.Mode of the DrugName:',df['DrugName'].mode())
print('12.Mode of the SubCat:',df['SubCat'].mode())
print('13.Mode of the SubCat1:',df['SubCat1'].mode())
# Out:
# 1.Mode of the Typeofsales: 0    Sale
# Name: Typeofsales, dtype: object
# 2.Mode of the Specialisation: 0    Specialisation4
# Name: Specialisation, dtype: object
# 3.Mode of the Dept: 0    Department1
# Name: Dept, dtype: object
# 4.Mode of the Dateofbill: 0    07-07-2022
# 1    07-09-2022
# Name: Dateofbill, dtype: object
# 5.Mode of the Quantity: 0    1
# Name: Quantity, dtype: int64
# 6.Mode of the ReturnQuantity: 0    0
# Name: ReturnQuantity, dtype: int64
# 7.Mode of the Final_Cost: 0    49.352
# Name: Final_Cost, dtype: float64
# 8.Mode of the Final_Sales: 0    0.0
# Name: Final_Sales, dtype: float64
# 9.Mode of the RtnMRP: 0    0.0
# Name: RtnMRP, dtype: float64
# 10.Mode of the Formulation: 0    Form1
# Name: Formulation, dtype: object
# 11.Mode of the DrugName: 0    SODIUM CHLORIDE IVF 100ML
# Name: DrugName, dtype: object
# 12.Mode of the SubCat: 0    INJECTIONS
# Name: SubCat, dtype: object
# 13.Mode of the SubCat1: 0    INTRAVENOUS & OTHER STERILE SOLUTIONS
# ...

# %% [markdown]
# # Second Order Business Decision

# %%
# variance,standard deviation,range

# %% [markdown]
# # Variance

# %%
#variance
print('Variance of the Quantity:',df['Quantity'].var())
print('Variance of the ReturnQuantity:',df['ReturnQuantity'].var())
print('Variance of the Final_Cost:',df['Final_Cost'].var())
print('Variance of the Final_Sales:',df['Final_Sales'].var())
print('Variance of the RtnMRP:',df['RtnMRP'].var())
# Out:
# Variance of the Quantity: 26.337862329084366
# Variance of the ReturnQuantity: 2.7005064023164533
# Variance of the Final_Cost: 216023.04539370985
# Variance of the Final_Sales: 450592.09766563325
# Variance of the RtnMRP: 33219.55893826576

# %% [markdown]
# # Standard Deviation

# %%
#standard deviation
print('Standard Deviation of the Quantity:',df['Quantity'].std())
print('Standard Deviation of the ReturnQuantity:',df['ReturnQuantity'].std())
print('Standard Deviation of the Final_Cost:',df['Final_Cost'].std())
print('Standard Deviation of the Final_Sales:',df['Final_Sales'].std())
print('Standard Deviation of the RtnMRP:',df['RtnMRP'].std())
# Out:
# Standard Deviation of the Quantity: 5.1320427053059845
# Standard Deviation of the ReturnQuantity: 1.6433217586085975
# Standard Deviation of the Final_Cost: 464.78279377975025
# Standard Deviation of the Final_Sales: 671.2615717182335
# Standard Deviation of the RtnMRP: 182.26233548999025

# %% [markdown]
# # Range

# %%
#range
print('Range of the Quantity:',df['Quantity'].max()-df['Quantity'].min())
print('Range of the ReturnQuantity:',df['ReturnQuantity'].max()-df['ReturnQuantity'].min())
print('Range of the Final_Cost:',df['Final_Cost'].max()-df['Final_Cost'].min())
print('Range of the Final_Sales:',df['Final_Sales'].max()-df.Final_Sales.min())
print('Range of the RtnMRP:',df['RtnMRP'].max()-df['RtnMRP'].min())
# Out:
# Range of the Quantity: 150
# Range of the ReturnQuantity: 50
# Range of the Final_Cost: 33138.0
# Range of the Final_Sales: 39490.0
# Range of the RtnMRP: 8014.0

# %% [markdown]
# # Third Order Business Decision

# %% [markdown]
# # Skewness

# %%
#skewness
print('Skewness of the Quantity:',df['Quantity'].skew())
print('Skewness of the ReturnQuantity:',df['ReturnQuantity'].skew())
print('Skewness of the Final_Cost:',df['Final_Cost'].skew())
print('Skewness of the Final_Sales:',df['Final_Sales'].skew())
print('Skewness of the RtnMRP:',df['RtnMRP'].skew())
# Out:
# Skewness of the Quantity: 11.34103427676747
# Skewness of the ReturnQuantity: 17.172364771343634
# Skewness of the Final_Cost: 34.508214502400946
# Skewness of the Final_Sales: 21.006721582359116
# Skewness of the RtnMRP: 15.797853037440984

# %% [markdown]
# # Fourth Order Business Decision

# %% [markdown]
# # Kurtosis

# %%
#kurtosis
print('Kurtosis of the Quantity:',df['Quantity'].kurt())
print('Kurtosis of the ReturnQuantity:',df['ReturnQuantity'].kurt())
print('Kurtosis of the Final_Cost:',df['Final_Cost'].kurt())
print('Kurtosis of the Final_Sales:',df['Final_Sales'].kurt())
print('Kurtosis of the RtnMRP:',df['RtnMRP'].kurt())
# Out:
# Kurtosis of the Quantity: 180.15385837022285
# Kurtosis of the ReturnQuantity: 409.41691374471526
# Kurtosis of the Final_Cost: 2025.8664752637628
# Kurtosis of the Final_Sales: 948.5227111226725
# Kurtosis of the RtnMRP: 403.52494081462515

# %% [markdown]
# # Visualization

# %%
df_num=df[['Quantity','ReturnQuantity','Final_Cost','Final_Sales','RtnMRP']]
df_num
# Out:
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP
# 0             1               0      55.406       59.260     0.0
# 1             1               0     768.638      950.800     0.0
# 2             1               0     774.266     4004.214     0.0
# 3             2               0      40.798       81.044     0.0
# 4             1               0      40.434       40.504     0.0
# ...         ...             ...         ...          ...     ...
# 14213         3               0      61.436      145.200     0.0
# 14214         2               0      64.448      119.692     0.0
# 14215         4               0      74.944      642.040     0.0
# 14216         1               0     111.680      181.000     0.0
# 14217         3               0      46.182      133.800     0.0
#
# [14218 rows x 5 columns]

# %%
df_num.corr()
# Out:
#                 Quantity  ReturnQuantity  Final_Cost  Final_Sales    RtnMRP
# Quantity        1.000000       -0.077264    0.017126     0.359877 -0.069499
# ReturnQuantity -0.077264        1.000000   -0.004076    -0.061947  0.509355
# Final_Cost      0.017126       -0.004076    1.000000     0.865818  0.152988
# Final_Sales     0.359877       -0.061947    0.865818     1.000000 -0.055721
# RtnMRP         -0.069499        0.509355    0.152988    -0.055721  1.000000

# %% [markdown]
# # HeatMap

# %%
sns.heatmap(df_num.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # PairPlot

# %%
sns.pairplot(df_num)

# %% [markdown]
# # histogram

# %%
# histogram for typeofsales
sns.histplot(df['Typeofsales'])
# Out:
# <Axes: xlabel='Typeofsales', ylabel='Count'>

# %%
# histogram for dept
sns.histplot(df['Dept'])
# Out:
# <Axes: xlabel='Dept', ylabel='Count'>

# %%
# histogram for formulation
sns.histplot(df['Formulation'])
# Out:
# <Axes: xlabel='Formulation', ylabel='Count'>

# %% [markdown]
# # distplot

# %%
# distplot
for i in df_num:
    skewd=df[i].skew()
    sns.distplot(df[i],label='Skewed=%.3f'%skewd,bins=30,color='purple')
    plt.legend()
    plt.show()

# %% [markdown]
# # Barplot

# %%
# barplot for quantity and other feature

# %%
# barplot for typeofsales and quantity
sns.barplot(x='Typeofsales',y='Quantity',data=df)
plt.show()

# %%
# barplot for dept and quantity
sns.barplot(x='Dept',y='Quantity',data=df)
plt.show()

# %%
# barplot for formulation and quantity
sns.barplot(x='Formulation',y='Quantity',data=df)
plt.show()

# %%
# barplot for SubCat and quantity
sns.barplot(x='SubCat',y='Quantity',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# barplot for SubCat1 and quantity
sns.barplot(x='SubCat1',y='Quantity',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# bar plot for finalcost and other features

# %%
#barplot for typeofsales and finalcost
sns.barplot(x='Typeofsales',y='Final_Cost',data=df)
plt.show()

# %%
# barplot for dept and finalcost
sns.barplot(x='Dept',y='Final_Cost',data=df)
plt.show()

# %%
# barplot for formulation and finalcost
sns.barplot(x='Formulation',y='Final_Cost',data=df)
plt.show()

# %%
# barplot for SubCat and finalcost
sns.barplot(x='SubCat',y='Final_Cost',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# barplot for SubCat1 and finalcost
sns.barplot(x='SubCat1',y='Final_Cost',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# bar plot for final_sales and other features

# %%
#barplot for typeofsales and finalsales
sns.barplot(x='Typeofsales',y='Final_Sales',data=df)
plt.show()

# %%
# barplot for dept and finalsales
sns.barplot(x='Dept',y='Final_Sales',data=df)
plt.show()

# %%
# barplot for formulation and finalsales
sns.barplot(x='Formulation',y='Final_Sales',data=df)
plt.show()

# %%
# barplot for SubCat and finalsales
sns.barplot(x='SubCat',y='Final_Sales',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# barplot for SubCat1 and finalsales
sns.barplot(x='SubCat1',y='Final_Sales',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # ScatterPlot

# %%
# scatterplot for quantity and finalcost
sns.scatterplot(x='Quantity',y='Final_Cost',data=df)
plt.show()

# %%
# scatterplot for quantity and finalsales
sns.scatterplot(x='Quantity',y='Final_Sales',data=df)
plt.show()

# %%
# scatterplot for finalcost and finalsales
sns.scatterplot(x='Final_Cost',y='Final_Sales',data=df)
plt.show()

# %%
sns.scatterplot(x='Dateofbill',y='Final_Sales',data=df)
plt.show()

# %%
sns.scatterplot(x='Dateofbill',y='Final_Cost',data=df)
plt.show()

# %% [markdown]
# # BoxPlot

# %%
df.plot(kind='box',figsize=(9,7),subplots=True,layout=(3,2),sharex=False,sharey=False)
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Data Cleaning

# %%
#dropping patient_id because it is not so used for model building
df.drop(['Patient_ID'],axis=1,inplace=True)

# %%
#fill na values
df['Formulation'].fillna(df['Formulation'].mode()[0],inplace=True)
df['DrugName'].fillna(df['DrugName'].mode()[0],inplace=True)
df['SubCat'].fillna(df['SubCat'].mode()[0],inplace=True)
df['SubCat1'].fillna(df['SubCat1'].mode()[0],inplace=True)

# %%
#all missing values are filled 
df.isna().sum()
# Out:
# Typeofsales       0
# Specialisation    0
# Dept              0
# Dateofbill        0
# Quantity          0
# ReturnQuantity    0
# Final_Cost        0
# Final_Sales       0
# RtnMRP            0
# Formulation       0
# DrugName          0
# SubCat            0
# SubCat1           0
# dtype: int64

# %%
#removing duplicate values
df.drop_duplicates(inplace=True)

# %%
# all duplicated values are removed
df.duplicated().sum()
# Out:
# 0

# %%
#From above boxplot we got to know in our data outliers are present
#so now removing the outlier
# removal of outliers are important because, when outliers are present it will affect the data

# %%
df_num
#it is the dataframe in which all our numeric data are present. So this numerical data containing outliers which is affecting our model.
# Out:
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP
# 0             1               0      55.406       59.260     0.0
# 1             1               0     768.638      950.800     0.0
# 2             1               0     774.266     4004.214     0.0
# 3             2               0      40.798       81.044     0.0
# 4             1               0      40.434       40.504     0.0
# ...         ...             ...         ...          ...     ...
# 14213         3               0      61.436      145.200     0.0
# 14214         2               0      64.448      119.692     0.0
# 14215         4               0      74.944      642.040     0.0
# 14216         1               0     111.680      181.000     0.0
# 14217         3               0      46.182      133.800     0.0
#
# [14218 rows x 5 columns]

# %%
#code for removal of outliers
num=[f for f in df.columns if df[f].dtypes!='O']
for i in num:
    q3=np.percentile(df[i],75)
    q1=np.percentile(df[i],25)
    iqr=q3-q1
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    
    df[i]=np.where(df[i]>ub,ub,df[i])
    df[i]=np.where(df[i]<lb,lb,df[i])

# %%
#after removal of outliers
#boxplot
#boxplot with no outliers
df.plot(kind='box',figsize=(9,7),subplots=True,layout=(3,2),sharex=False,sharey=False)
plt.show()

# %%
df.dtypes
# Out:
# Typeofsales        object
# Specialisation     object
# Dept               object
# Dateofbill         object
# Quantity          float64
# ReturnQuantity    float64
# Final_Cost        float64
# Final_Sales       float64
# RtnMRP            float64
# Formulation        object
# DrugName           object
# SubCat             object
# SubCat1            object
# dtype: object

# %%
df
# Out:
#       Typeofsales    Specialisation         Dept  Dateofbill  Quantity  \
# 0            Sale   Specialisation6  Department1  06-01-2022       1.0
# 1            Sale   Specialisation7  Department1   7/23/2022       1.0
# 2            Sale   Specialisation2  Department3   6/23/2022       1.0
# 3            Sale  Specialisation40  Department1   3/17/2022       2.0
# 4            Sale   Specialisation5  Department1  12/21/2022       1.0
# ...           ...               ...          ...         ...       ...
# 14213        Sale  Specialisation39  Department1   6/19/2022       3.0
# 14214        Sale   Specialisation4  Department1   2/24/2022       2.0
# 14215        Sale   Specialisation1  Department1   6/27/2022       3.5
# 14216        Sale  Specialisation20  Department1   7/30/2022       1.0
# 14217        Sale  Specialisation26  Department1  10/24/2022       3.0
#
#        ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %%
#here typeofsales are dependent feature(y)

# %% [markdown]
# # Label Encoding

# %%
# so for model building we have to convert in numerics
# It is done using LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# label encoding using for loop
l=[i for i in df.columns if df[i].dtypes=='O']
for i in l:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        Typeofsales  Specialisation  Dept  Dateofbill  Quantity  \
# 0                1              47     0          60       1.0
# 1                1              53     0         319       1.0
# 2                1              11     2         301       1.0
# 3                1              30     0         239       2.0
# 4                1              38     0         208       1.0
# ...            ...             ...   ...         ...       ...
# 14213            1              28     0         297       3.0
# 14214            1              29     0         230       2.0
# 14215            1               0     0         305       3.5
# 14216            1              12     0         326       1.0
# 14217            1              18     0         150       3.0
#
#        ReturnQuantity  Final_Cost  Final_Sales  RtnMRP  Formulation  DrugName  \
# 0                 0.0      55.406       59.260     0.0            0       746
# ...

# %% [markdown]
# # Feature Scaling

# %%
# we have data with different scales.So we need to perform standardization for equalize the scale.

# %%
#standardization
from sklearn.preprocessing import StandardScaler
st=StandardScaler()

# %%
df.iloc[:,:]=st.fit_transform(df.iloc[:,:])
df
# Out:
#        Typeofsales  Specialisation      Dept  Dateofbill  Quantity  \
# 0         0.367634        1.149876 -0.362131   -1.186482 -0.510249
# 1         0.367634        1.503537 -0.362131    1.262932 -0.510249
# 2         0.367634       -0.972092  4.792862    1.092703 -0.510249
# 3         0.367634        0.147835 -0.362131    0.506356  0.435744
# 4         0.367634        0.619384 -0.362131    0.213183 -0.510249
# ...            ...             ...       ...         ...       ...
# 14213     0.367634        0.029948 -0.362131    1.054874  1.381737
# 14214     0.367634        0.088892 -0.362131    0.421242  0.435744
# 14215     0.367634       -1.620472 -0.362131    1.130532  1.854733
# 14216     0.367634       -0.913149 -0.362131    1.329133 -0.510249
# 14217     0.367634       -0.559487 -0.362131   -0.335334  1.381737
#
#        ReturnQuantity  Final_Cost  Final_Sales  RtnMRP  Formulation  DrugName  \
# 0                 0.0   -0.392567    -0.604709     0.0    -0.341323  1.401294
# ...

# %% [markdown]
# # Pandas Profiling

# %%
import ydata_profiling as pp

# %%
eda_report=pp.ProfileReport(df)

# %%
eda_report.to_file(output_file='eda_report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
